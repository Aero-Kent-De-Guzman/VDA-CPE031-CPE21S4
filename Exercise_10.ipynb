# %% [markdown]
# <a href="https://colab.research.google.com/github/Aero-Kent-De-Guzman/VDA-CPE031-CPE21S4/blob/main/Exercise_10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Regression and Correlation**

# %%
# !pip install numpy
# !pip install pandas
# !pip install matplotlib

# %% [markdown]
# **Regression Line Example**

# %%
import numpy as np
import matplotlib.pyplot as plt

# Generate data
x = np.array([1,2,3,4,5])
y = np.array([2,4,5,4,5])

# Calculate the slope and y-intercept of the regression line
slope, intercept = np.polyfit(x,y,1)

# Calculate the predicted values of y using the regression line equation
y_pred = slope * x + intercept

# Plot the original data points and the regression line
plt.scatter(x,y)
plt.plot(x,y_pred,color='red')
plt.title('Regression Line')
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %% [markdown]
# **Regression line with a given CSV**

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-ad99b7cd-1dbc-4392-b9cb-b9f24c9436ed" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ad99b7cd-1dbc-4392-b9cb-b9f24c9436ed">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

data = pd.read_csv("Sample Data 26-11-24 - Sheet1.csv")
df = pd.DataFrame(data)
df
# Out:
#    Student Number  Proficiency Exam Score  Course Grade
# 0               1                      60            70
# 1               2                      90            95
# 2               3                      70            70
# 3               4                      85            75
# 4               5                      80            90
# 5               6                      65            75
# 6               7                      75            75
# 7               8                      60            60
# 8               9                      75            80
# 9              10                      70            65

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

x1 = df["Proficiency Exam Score"]
y1 = df["Course Grade"]

slope, intercept = np.polyfit(x1,y1,1)
y1_pred = slope * x1 + intercept

plt.scatter(x1,y1)
plt.plot(x1,y1_pred,color='red')
plt.title('Regression Line using CSV data')
plt.xlabel('Proficiency Exam Score')
plt.ylabel('Course Grade')
plt.show()
