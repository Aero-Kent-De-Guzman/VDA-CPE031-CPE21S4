# %% [markdown]
# <a href="https://colab.research.google.com/github/Aero-Kent-De-Guzman/VDA-CPE031-CPE21S4/blob/main/LaboratoryManualActivity.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Loading your dataset**

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-fb05a43c-af76-4fc2-ac95-daaed2c98473" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-fb05a43c-af76-4fc2-ac95-daaed2c98473">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# # **Creating a dataframe from your CSV file**

# %%
import pandas as pd

data = pd.read_csv('user_behavior_dataset.csv')
df = pd.DataFrame(data)
print(df)
# Out:
#      User ID        Device Model Operating System  App Usage Time (min/day)  \
# 0          1      Google Pixel 5          Android                       393
# 1          2           OnePlus 9          Android                       268
# 2          3        Xiaomi Mi 11          Android                       154
# 3          4      Google Pixel 5          Android                       239
# 4          5           iPhone 12              iOS                       187
# ..       ...                 ...              ...                       ...
# 695      696           iPhone 12              iOS                        92
# 696      697        Xiaomi Mi 11          Android                       316
# 697      698      Google Pixel 5          Android                        99
# 698      699  Samsung Galaxy S21          Android                        62
# 699      700           OnePlus 9          Android                       212
#
# ...

# %% [markdown]
# # **Creating a dataframe from a dictionary of lists**

# %%
DataDictionary = {
    'App-Usage Time'            : df['App Usage Time (min/day)'].head(700),
    'Screen-On Time'            : df['Screen On Time (hours/day)'].head(700),
    'Battery Drain'             : df['Battery Drain (mAh/day)'].head(700),
    'Number of Apps Installed'  : df['Number of Apps Installed'].head(700),
    'Data Usage'                : df['Data Usage (MB/day)'].head(700),
    'User Behavior Class'       : df['User Behavior Class'].head(700)
}

newDF = pd.DataFrame(DataDictionary)
print(newDF.head(10))
# Out:
#    App-Usage Time  Screen-On Time  Battery Drain  Number of Apps Installed  \
# 0             393             6.4           1872                        67
# 1             268             4.7           1331                        42
# 2             154             4.0            761                        32
# 3             239             4.8           1676                        56
# 4             187             4.3           1367                        58
# 5              99             2.0            940                        35
# 6             350             7.3           1802                        66
# 7             543            11.4           2956                        82
# 8             340             7.7           2138                        75
# 9             424             6.6           1957                        75
#
#    Data Usage  User Behavior Class
# 0        1122                    4
# 1         944                    3
# 2         322                    2
# ...

# %% [markdown]
# # **Creating a dataframe from a list of dictionaries**

# %%
DataList = [
  {
    'App-Usage Time'            : 393,
    'Screen-On Time'            : 6.4,
    'Battery Drain'             : 1872,
    'Number of Apps Installed'  : 67,
    'Data Usage'                : 1122,
    'User Behavior Class'       : 4
  },
  {
    'App-Usage Time'            : 268,
    'Screen-On Time'            : 4.7,
    'Battery Drain'             : 1331,
    'Number of Apps Installed'  : 42,
    'Data Usage'                : 944,
    'User Behavior Class'       : 3
  },
    {
    'App-Usage Time'            : 154,
    'Screen-On Time'            : 4.0,
    'Battery Drain'             : 761,
    'Number of Apps Installed'  : 32,
    'Data Usage'                : 322,
    'User Behavior Class'       : 2
  },
    {
    'App-Usage Time'            : 239,
    'Screen-On Time'            : 4.8,
    'Battery Drain'             : 1676,
    'Number of Apps Installed'  : 56,
    'Data Usage'                : 871,
    'User Behavior Class'       : 3
  },
    {
    'App-Usage Time'            : 187,
    'Screen-On Time'            : 4.3,
    'Battery Drain'             : 1367,
    'Number of Apps Installed'  : 58,
    'Data Usage'                : 988,
    'User Behavior Class'       : 3
  },

]

DFlist = pd.DataFrame(DataList)
print(DFlist)
# Out:
#    App-Usage Time  Screen-On Time  Battery Drain  Number of Apps Installed  \
# 0             393             6.4           1872                        67
# 1             268             4.7           1331                        42
# 2             154             4.0            761                        32
# 3             239             4.8           1676                        56
# 4             187             4.3           1367                        58
#
#    Data Usage  User Behavior Class
# 0        1122                    4
# 1         944                    3
# 2         322                    2
# 3         871                    3
# 4         988                    3

# %% [markdown]
# # **Selecting dataframe columns**

# %%
print('Originial dataframe')
print(df)
print('Only Getting one Column')
print(df['App Usage Time (min/day)'])
# Out:
# Originial dataframe
#      User ID        Device Model Operating System  App Usage Time (min/day)  \
# 0          1      Google Pixel 5          Android                       393
# 1          2           OnePlus 9          Android                       268
# 2          3        Xiaomi Mi 11          Android                       154
# 3          4      Google Pixel 5          Android                       239
# 4          5           iPhone 12              iOS                       187
# ..       ...                 ...              ...                       ...
# 695      696           iPhone 12              iOS                        92
# 696      697        Xiaomi Mi 11          Android                       316
# 697      698      Google Pixel 5          Android                        99
# 698      699  Samsung Galaxy S21          Android                        62
# 699      700           OnePlus 9          Android                       212
#
# ...

# %% [markdown]
# # **Selecting Dataframe Rows**

# %%
print('Originial dataframe')
print(df)
print('Only Getting Specific Rows')
print('first 10')
print(df.head(10))
print('last 10')
print(df.tail(10))
print('specific 1')
print(df.loc[5])
# Out:
# Originial dataframe
#      User ID        Device Model Operating System  App Usage Time (min/day)  \
# 0          1      Google Pixel 5          Android                       393
# 1          2           OnePlus 9          Android                       268
# 2          3        Xiaomi Mi 11          Android                       154
# 3          4      Google Pixel 5          Android                       239
# 4          5           iPhone 12              iOS                       187
# ..       ...                 ...              ...                       ...
# 695      696           iPhone 12              iOS                        92
# 696      697        Xiaomi Mi 11          Android                       316
# 697      698      Google Pixel 5          Android                        99
# 698      699  Samsung Galaxy S21          Android                        62
# 699      700           OnePlus 9          Android                       212
#
# ...
